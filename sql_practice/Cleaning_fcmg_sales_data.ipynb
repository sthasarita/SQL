# %%
import pandas as pd

# %%
df = pd.read_csv("Indian FMCG Retail Sales  Customer  Inventory (2024).csv")

# %%
df
# Out:
#        Invoice_ID         Invoice_Date       City Store_Format   Category  \
# 0        58018430  2024-02-02 13:50:00    Kolkata        Super    Grocery
# 1        48157952  2024-10-09 11:52:00  Hyderabad        Hyper  Home Care
# 2        23283831  2024-08-26 22:03:00    Chennai        Hyper     Snacks
# 3        53537460  2024-06-09 04:34:00  Bengaluru        Hyper  Beverages
# 4        55348596  2024-06-07 01:13:00      Delhi        Super     Snacks
# ...           ...                  ...        ...          ...        ...
# 99995    51439182  2024-08-11 14:58:00     Mumbai      Express      Dairy
# 99996    76433622  2024-11-27 11:02:00  Ahmedabad      Express      Dairy
# 99997    80228351  2024-02-21 09:25:00  Bengaluru      Express  Beverages
# 99998    49574701  2024-03-30 04:11:00    Chennai        Hyper      Dairy
# 99999    17631041  2024-07-11 08:42:00       Pune        Super     Snacks
#
#            Brand      Channel Payment_Mode  Units  Cost_Price  ...  \
# ...

# %%
df["Selling_Price"].head()
# Out:
# 0    175.057209
# 1    106.034197
# 2    208.980023
# 3    260.879960
# 4     30.624472
# Name: Selling_Price, dtype: float64

# %%
df.columns
# Out:
# Index(['Invoice_ID', 'Invoice_Date', 'City', 'Store_Format', 'Category',
#        'Brand', 'Channel', 'Payment_Mode', 'Units', 'Cost_Price',
#        'Selling_Price', 'Revenue', 'Cost', 'Margin', 'Margin_%',
#        'Stock_On_Hand', 'Reorder_Level', 'Lead_Time_Days', 'Customer_Age',
#        'Customer_Gender', 'Loyalty_Flag'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 21 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Invoice_ID       100000 non-null  int64
#  1   Invoice_Date     100000 non-null  str
#  2   City             100000 non-null  str
#  3   Store_Format     100000 non-null  str
#  4   Category         100000 non-null  str
#  5   Brand            100000 non-null  str
#  6   Channel          100000 non-null  str
#  7   Payment_Mode     100000 non-null  str
#  8   Units            100000 non-null  int64
#  9   Cost_Price       100000 non-null  float64
#  10  Selling_Price    100000 non-null  float64
#  11  Revenue          100000 non-null  float64
#  12  Cost             100000 non-null  float64
#  13  Margin           100000 non-null  float64
#  14  Margin_%         100000 non-null  float64
#  15  Stock_On_Hand    100000 non-null  int64
#  16  Reorder_Level    100000 non-null  int64
# ...

# %%
df["Customer_Age"].value_counts()
# Out:
# Customer_Age
# 55.0    1343
# 57.0    1343
# 59.0    1334
# 38.0    1328
# 49.0    1326
# 31.0    1326
# 27.0    1320
# 43.0    1316
# 36.0    1307
# 64.0    1305
# 42.0    1302
# 45.0    1299
# 40.0    1296
# 30.0    1291
# 51.0    1291
# 46.0    1288
# 58.0    1288
# 21.0    1287
# 33.0    1284
# 63.0    1283
# 61.0    1281
# 24.0    1281
# 52.0    1280
# 48.0    1278
# 18.0    1271
# 29.0    1271
# 20.0    1269
# 37.0    1269
# 54.0    1269
# 19.0    1262
# 60.0    1259
# 50.0    1259
# 28.0    1254
# 35.0    1253
# 23.0    1252
# 62.0    1250
# 39.0    1245
# 47.0    1245
# 44.0    1244
# 25.0    1242
# 22.0    1240
# 34.0    1236
# 53.0    1235
# 32.0    1231
# 26.0    1210
# 56.0    1205
# 41.0    1171
# Name: count, dtype: int64

# %%
df["Customer_Age"].nunique()
# Out:
# 47

# %%
df["Customer_Age"].mean()
# Out:
# np.float64(41.0766201038068)

# %%
df["Customer_Age"].isnull().sum()
# Out:
# np.int64(40081)

# %%
df['Customer_Age'] = df['Customer_Age'].fillna(df['Customer_Age'].median())

df['Customer_Gender'] = df['Customer_Gender'].fillna('Unknown')

# %%
df[['Customer_Age', 'Customer_Gender']].isnull().sum()
# Out:
# Customer_Age       0
# Customer_Gender    0
# dtype: int64

# %%
df.to_csv("FMCG Retail Sales  Customer  Inventory.csv", index = False)
